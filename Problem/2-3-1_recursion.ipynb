# %% [markdown]
# # 2.3 再起プログラミング
# ある関数から自分自身を呼び出すことを，再帰呼び出しという。
# 文字列を再帰的に書き換えて成長させるプログラムを書いてみよう。
#
# f,g,hの文字列のうち，
#
# - f -> fg
# - g -> gh
# - h -> gf
#
# となるようにする。

# %%
def grow(s, r):  # 文字列sと繰り返し回数rを入力
    num = len(s)
    ss = ''  # 出力する文字列を初期化
    for i in range(num): #文字列を一文字ずつ取り出してループする
        if s[i] == 'f':
            ss = ss + 'fg'# ' f'  を ' fg'  に書き換え 
        elif s[i] == 'g':
            ss = ss + 'gh'# ' g'  を ' gh'  に書き換え
        elif s[i] == 'h':
            ss = ss + 'hf'# hをgfに書き換え
        else:
            ss = ss + s[i]
    print(ss)
    r -= 1 # 残りの繰返し回数を1減らす
    if r > 0:
        grow(ss,r)# 繰返し回数が0でない時，自分自身を呼び出す
    return ss

# %%
grow('fXgXh', 5)  # growを2回実行
# Out:
# fgXghXhf
# fgghXghhfXhffg
# fgghghhfXghhfhffgXhffgfggh
# fgghghhfghhfhffgXghhfhffghffgfgghXhffgfgghfgghghhf
# fgghghhfghhfhffgghhfhffghffgfgghXghhfhffghffgfgghhffgfgghfgghghhfXhffgfgghfgghghhffgghghhfghhfhffg
# 'fgXghXhf'

# %% [markdown]
# # 二次元図形の入れ子
# 文字列は1次元。
# 次にturtleを用いて，2次元図形が入れ子になったものを描こう。
#
# ## turtle graphic
# https://docs.python.org/ja/3.6/library/turtle.html?highlight=turtle#module-turtle
# https://www.101computing.net/2d-shapes-using-python-turtle/
#
# ## 建築の例
# 例えば，伊東豊雄＋セシル・バルモンド ＜サーペンタインギャラリーパビリオン＞（2002）。
# http://www.toyo-ito.co.jp/WWW/Project_Descript/2000-/2000-p_08/2000-p_08_j.html

# %%
from turtle import *  # 描画環境 turtle をインポート

# %% [markdown]
# 点群を読み込んで，それをつないで描画する関数。

# %%
def connect_points(points):
    up()
    setpos(points[-1][0], points[-1][1])
    down()
    for xy in points:
        setpos(xy[0], xy[1])

# %% [markdown]
# n角形の頂点群座標を返す関数。描画はしない。

# %%
def n_polygon(n=4, x0=0, y0=0, size=100):
    angle = 360 / n
    up()
    setpos(x0, y0)
    points = []
    for i in range(n):
        forward(size)
        left(angle)
        points.append(pos())
    return points

# %% [markdown]
# 値p0と値p1をrで内分する点を返す関数と，座標p0と座標p1について同じことをする関数。

# %%
def deviding(p0, p1, r):
    # 書く
    return p0 * (1 - r) + p1 * r

# %%
# deviding_point(点A,点B,内分比)
def deviding_point(p0, p1, ratio):
    # 書く
    [x0,y0] = p0
    [x1,y1] = p1
    xr = deviding(x0,x1,ratio)
    yr = deviding(y0,y1,ratio)
    return [xr, yr]

# %% [markdown]
# さらに多角形の各辺を内分してその頂点群を返す関数

# %%
# deviding_points(多角形の４頂点，内分比)
def deviding_points(points, ratio):
    new_points = []
    points2 = points[:] #コピーを作成
    points2.append(points2[0])
    points2.pop(0)
    for p0, p1 in zip(points, points2):
        pr0 = deviding_point(p0,p1,ratio)
        new_points.append(pr0)
        #書く
    return new_points

# %% [markdown]
# 再帰呼び出し関数

# %%
def rose_window_recursion(points, ratio, depth):
    connect_points(points)
    new_points = deviding_points(points, ratio)
    if depth == 0:
        up()
        setpos(-200, -200)
    else:
        rose_window_recursion(new_points, ratio, depth - 1)

# %% [markdown]
# それでは実行してみよう。最初に`n_polygon`関数でn角形の頂点座標を取り出し，それを読み込んで再帰的に描画して行こう。
# turtleはブラウザの外の画面で実行されます。

# %%
speed(0)
points = n_polygon(n=13, size=100)
rose_window_recursion(points, 0.1, 400)
done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-102-7a38a3f29984> in <module>()
#       1 speed(0)
#       2 points = n_polygon(n=13, size=100)
# ----> 3 rose_window_recursion(points, 0.1, 400)
#       4 done()
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       6         setpos(-200, -200)
#       7     else:
# ----> 8         rose_window_recursion(new_points, ratio, depth - 1)
#
# <ipython-input-94-26b880f9eb20> in rose_window_recursion(points, ratio, depth)
#       1 def rose_window_recursion(points, ratio, depth):
# ----> 2     connect_points(points)
#       3     new_points = deviding_points(points, ratio)
#       4     if depth == 0:
#       5         up()
#
# <ipython-input-89-12c3f5ae5621> in connect_points(points)
#       4     down()
#       5     for xy in points:
# ----> 6         setpos(xy[0], xy[1])
#
# ~\Anaconda3\lib\turtle.py in setpos(x, y)
#
# Terminator:
